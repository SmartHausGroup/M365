# %% [markdown]
# # M365 Contracts Projection Notebook
#
# Bridge notebook for UCP module-contract phase alignment. It aggregates the existing contract verification artifacts for the M365 repo.

# %%
import json
from pathlib import Path

caio = json.loads(Path('configs/generated/caio_m365_contract_verification.json').read_text())
cap = json.loads(Path('configs/generated/capability_registry_verification.json').read_text())
auth = json.loads(Path('configs/generated/m365_auth_verification.json').read_text())
idem = json.loads(Path('configs/generated/m365_idempotency_verification.json').read_text())
audit = json.loads(Path('configs/generated/m365_audit_verification.json').read_text())
assert caio['response_schema_pass'] is True
assert caio['postcondition_pass'] is True
assert cap['passed'] is True
assert auth['auth_pass'] is True
assert idem['idempotency_pass'] is True
assert audit['audit_pass'] is True
print('m365 contract projection green')
