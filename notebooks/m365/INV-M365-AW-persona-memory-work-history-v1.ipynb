# %% [markdown]
# # INV-M365-AW Persona Memory and Work History v1
#
# ## Purpose
# Prove that persona memory and replayable work history remain bounded and auditable only when they are projected from one authority and one shared runtime.
#
# ## Lemma Mapping
# - L47
#
# ## Invariant Support
# - invariants/lemmas/L47_m365_persona_memory_work_history_v1.yaml
#
# ## Expected Result
# - Memory writes are bounded and work history is replayable from explicit records.

# %%
from pathlib import Path

root = Path.cwd()
assert (root / 'registry' / 'persona_memory_work_history_v1.yaml').exists()
assert (root / 'src' / 'smarthaus_common' / 'persona_memory.py').exists()
assert (root / 'tests' / 'test_persona_memory_work_history_v1.py').exists()
