# %% [markdown]
# # INV-M365-AI — Power Automate Expansion v2
#
# - Purpose: lock the first bounded Power Automate workload slice into the v2 control plane.
# - Lemma mapping: `L33`.
# - Invariant support: `L33_m365_power_automate_expansion_v2`.
# - Expected result: the instruction API, capability registry, routing/auth/approval contracts, and bounded Power Automate runtime all agree on the E3A flow actions.

# %% [markdown]
# ## Notebook-first extraction note
#
# The runtime extraction for `E3A` is bounded to administrative Power Automate surfaces plus explicit callback invocation. Any missing PowerShell module or missing service-principal credential path is a fail-closed condition, not a fallback to implicit portal behavior.
