# %% [markdown]
# # INV-M365-O — Entra App Separation and Certificate Cutover
#
# **Purpose:** Establish notebook-backed traceability for the SMARTHAUS Entra app-registration cleanup by proving that standalone enterprise certification must remain blocked until the operator-identity app and backend executor app are explicitly separated and the executor app has a certificate-cutover contract.
#
# **Lemma mapping:** `L13`
#
# **Invariant support:** explicit operator-versus-executor app separation, certificate-targeted executor credential posture, and `C1A` prerequisite gating behind `B5D` and `B5E`.
#
# **Expected results:** The active plan inserts `B5D` and `B5E` before `C1A`, the executor app remains the tenant-selected app-only Graph executor, and the operator-identity app is treated as the Entra user-auth plane rather than an overlapping service principal.
