# %% [markdown]
# # INV-M365-AQ — Conditional Access / Identity Protection Expansion v2
#
# - Purpose: Bound the E4D conditional-access and identity-protection slice.
# - Lemma mapping: L41.
# - Invariant support: `L41_m365_conditional_access_identity_protection_expansion_v2`.
# - Expected result: router, registry, auth, approval, and verifier agreement for the E4D action family.
