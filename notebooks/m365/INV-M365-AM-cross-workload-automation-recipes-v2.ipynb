# %% [markdown]
# # INV-M365-AM — Cross-Workload Automation Recipes v2
#
# Purpose: prove the bounded cross-workload recipe authority, runtime discovery surface, routing, auth, approvals, and verification contract for `E3E`.
#
# Lemma mapping: `L37_m365_cross_workload_automation_recipes_v2`.
#
# Invariant support: `invariants/lemmas/L37_m365_cross_workload_automation_recipes_v2.yaml`.
#
# Expected result: recipe catalog actions are instruction-backed, capability-backed, routed to `composite`, app-only, approval-profile aligned, and every declared recipe spans multiple workloads while referencing only implemented actions.

# %% [markdown]
# Deterministic validation is extracted into `scripts/ci/verify_cross_workload_automation_recipes.py` and `tests/test_cross_workload_automation_recipes_v2.py`. Runtime code is only accepted after those bounded proofs remain green.
