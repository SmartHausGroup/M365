# %% [markdown]
# # INV-M365-R Runtime Executor Routing and Domain Selection
#
# Purpose: back `B7B` by proving the governed runtime can resolve one bounded executor for each supported action while preserving approval and audit semantics.
#
# Lemma mapping: `L16`
#
# Invariant support: `invariants/lemmas/L16_m365_runtime_executor_routing_domain_selection.yaml`
#
# Expected result: supported actions route deterministically, unmapped routes fail closed, and the approvals backend binds to the SharePoint executor path.
