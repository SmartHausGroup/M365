# %% [markdown]
# # INV-M365-P — Digital Employee and Executor-Domain Architecture
#
# Purpose: notebook-backed governance source for the B6 architecture correction.
#
# Lemma mapping: L14.
#
# Invariant support: digital employees are modeled above bounded executor domains; certification is rebased away from the single-executor posture.
