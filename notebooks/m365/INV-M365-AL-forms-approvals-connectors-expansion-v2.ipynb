# %% [markdown]
# # INV-M365-AL — Forms / Approvals / Connectors Expansion v2
#
# Purpose: prove the bounded approvals-app and connector workload authority, runtime projection, routing, auth, approvals, and verification contract for `E3D`.
#
# Lemma mapping: `L36_m365_forms_approvals_connectors_expansion_v2`.
#
# Invariant support: `invariants/lemmas/L36_m365_forms_approvals_connectors_expansion_v2.yaml`.
#
# Expected result: all declared approvals and connector actions are instruction-backed, capability-backed, routed to `powerplatform` or `knowledge` as documented, auth-class aligned, and approval-profile aligned.

# %% [markdown]
# Deterministic validation is extracted into `scripts/ci/verify_forms_approvals_connectors_expansion.py` and `tests/test_forms_approvals_connectors_expansion_v2.py`. Runtime code is only accepted after those bounded proofs remain green.
