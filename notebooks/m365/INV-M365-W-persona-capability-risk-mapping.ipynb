# %% [markdown]
# # INV-M365-W — Persona Capability and Risk Mapping
#
# Purpose: notebook-backed governance source for E0D persona-to-capability, risk, and approval binding.
#
# Lemma mapping: L21.
#
# Invariant support: every authoritative persona is bound to workload families, capability families, approval posture, and coverage status without silently promoting non-authoritative registry agents.
