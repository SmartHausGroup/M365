# %% [markdown]
# # INV-M365-L — Mypy Stub and Module-Path Remediation
#
# **Purpose:** Establish notebook-backed traceability for `B4D4` by pinning the governed Mypy blocker set: missing `yaml` typing support and duplicate module discovery for `src/ops_adapter/actions.py`.
#
# **Lemma mapping:** `L10`
#
# **Invariant support:** explicit typing dependencies, unique module-path resolution, actionable governed-path Mypy output.
#
# **Expected result:** after the bounded remediation, the governed Mypy hook fails only on real type diagnostics, not environment or path-mapping blockers.
