# %% [markdown]
# # Purpose
#
# Prove the task orchestration contract is bounded and deterministic.
#
# ## Lemma Mapping
#
# - L60 — M365 Task Orchestration Contract v1

# %%
from pathlib import Path
import yaml

contract = yaml.safe_load((Path.cwd() / 'registry' / 'task_orchestration_contract_v1.yaml').read_text(encoding='utf-8'))

assert len(contract['orchestration_primitives']) == 4
assert len(contract['step_contract']['step_states']) == 6
assert len(contract['step_contract']['required_fields']) == 6
assert len(contract['governance_rules']) == 4
