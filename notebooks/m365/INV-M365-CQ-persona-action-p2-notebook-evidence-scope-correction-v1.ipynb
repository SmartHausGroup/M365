# %% [markdown]
# # INV-M365-CQ Persona-Action P2 Notebook Evidence Scope Correction v1
#
# Purpose: freeze the first bounded `P2` blocker truth so the parent remediation may reopen the blocked legacy-stub code-write validation.
#
# Lemma mapping:
# - `L90_m365_persona_action_legacy_stub_remediation_v1`
#
# Invariant support:
# - `L90_m365_persona_action_legacy_stub_remediation_v1.yaml`

# %%
verification = {
    "status": "persona_action_p2_notebook_evidence_scope_correction_ready",
    "blocked_write_set": [
        "src/ops_adapter/actions.py",
        "tests/test_ops_adapter.py",
    ],
    "target_aliases": ["task.create", "follow-up.schedule", "reminder.send"],
    "legacy_stub_backlog": {"active_pairs": 49, "unique_aliases": 48},
    "blocked_validation": {"verdict": "allowed:false", "violation": "map-2-code-notebook-required"},
    "future_l90_chain": {
        "lemma": "docs/ma/lemmas/L90_m365_persona_action_legacy_stub_remediation_v1.md",
        "invariant": "invariants/lemmas/L90_m365_persona_action_legacy_stub_remediation_v1.yaml",
        "notebook": "notebooks/m365/INV-M365-CR-persona-action-legacy-stub-remediation-v1.ipynb",
        "lemma_notebook": "notebooks/lemma_proofs/L90_m365_persona_action_legacy_stub_remediation_v1.ipynb",
        "scorecard": "artifacts/scorecards/scorecard_l90.json",
        "verification": "configs/generated/persona_action_legacy_stub_remediation_v1_verification.json"
    }
}
assert verification["legacy_stub_backlog"]["unique_aliases"] == 48
assert verification["blocked_validation"]["violation"] == "map-2-code-notebook-required"
verification
