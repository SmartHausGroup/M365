# %% [markdown]
# # INV-M365-T Executor Permission Minimization and Azure Cleanup
#
# Purpose: back `B7D` by proving that the live SMARTHAUS tenant has moved from the monolithic executor posture to bounded SharePoint, collaboration, and directory executors with certificate-backed credentials and deterministic routing.
#
# Lemma mapping: `L18`
#
# Invariant support: `L18_m365_executor_permission_minimization_azure_cleanup.yaml`
#
# Expected result: each bounded executor carries only the roles needed for its supported surface, the legacy executor is no longer the active default, and representative app-only Graph probes return success for SharePoint, collaboration, and directory.
