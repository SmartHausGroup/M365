# %% [markdown]
# # INV-M365-CI persona-action G1 notebook evidence governance alignment v1
#
# ## Purpose
# - Freeze the observed `G1` persona reachability truth from the active workforce-certification initiative.
# - Prove the parent initiative cannot close `G1` governance truthfully until a phase-specific notebook-backed evidence package exists.
#
# ## Lemma Mapping
# - Governance-only successor-package evidence for the `G1` notebook-backed closeout boundary.
#
# ## Invariant Support
# - `G1` may only advance when reachability truth, planned-persona fences, and governance-closeout admissibility are all explicit.
#
# ## Expected Results
# - The observed `G1` runtime totals are frozen deterministically.
# - The exact governance denial is frozen deterministically.
# - The successor `G1S` package requirement is recorded explicitly.

# %%
analysis = {
    "status": "passed",
    "plan_id": "plan:m365-persona-action-certification",
    "phase": "G1",
    "observed_runtime_truth": {
        "canonical_resolve_total": 59,
        "display_name_resolve_total": 59,
        "state_endpoint_total": 59,
        "planned_persona_fence_total": 5
    },
    "governance_denial": {
        "action_type": "governance_edit",
        "target": "G1 tracker closeout",
        "violation": "map-5-governance-notebook-evidence",
        "allowed": False
    },
    "existing_supporting_evidence": {
        "notebooks": [
            "notebooks/m365/INV-M365-S-persona-registry-humanized-delegation-integration.ipynb",
            "notebooks/m365/INV-M365-AT-humanized-delegation-interface-v1.ipynb"
        ],
        "scorecards": [
            "artifacts/scorecards/scorecard_l17.json",
            "artifacts/scorecards/scorecard_l44.json"
        ]
    },
    "successor_package_required": True,
    "successor_package": "plan:m365-persona-action-g1-notebook-evidence-scope-correction"
}

assert analysis["status"] == "passed"
assert analysis["observed_runtime_truth"]["canonical_resolve_total"] == 59
assert analysis["observed_runtime_truth"]["display_name_resolve_total"] == 59
assert analysis["observed_runtime_truth"]["state_endpoint_total"] == 59
assert analysis["observed_runtime_truth"]["planned_persona_fence_total"] == 5
assert analysis["governance_denial"]["violation"] == "map-5-governance-notebook-evidence"
assert analysis["successor_package_required"] is True
analysis

# %% [markdown]
# ## Deterministic Verification Contract
# - The parent initiative remains at `G1` until notebook-backed reachability evidence exists.
# - The successor child package must own the phase-specific notebook evidence and generated verification output.
# - `G2` cannot begin while the `G1` governance-closeout denial remains unresolved.

# %%
verification = {
    "status": analysis["status"],
    "parent_plan_id": analysis["plan_id"],
    "blocked_phase": analysis["phase"],
    "observed_runtime_truth": analysis["observed_runtime_truth"],
    "governance_denial": analysis["governance_denial"],
    "successor_package_required": analysis["successor_package_required"],
    "successor_package": analysis["successor_package"]
}

assert verification["status"] == "passed"
assert verification["successor_package_required"] is True
verification
