# %% [markdown]
# # INV-M365-CPS-C2 — Planned-Action Short-Circuit v1
#
# **Lemma:** `L110_m365_cps_c2_planned_short_circuit_v1`

# %%
import sys, random
from pathlib import Path
random.seed(0)
REPO = Path.cwd()
while not (REPO / 'src' / 'm365_runtime').is_dir() and REPO.parent != REPO:
    REPO = REPO.parent
if str(REPO / 'src') not in sys.path:
    sys.path.insert(0, str(REPO / 'src'))
from ucp_m365_pack.client import compute_coverage_status
assert compute_coverage_status('graph.me') == 'implemented'
assert compute_coverage_status('me.read') == 'aliased'
assert compute_coverage_status('completely.bogus') == 'planned'
print('PlannedShortCircuitValid: True')
