# %% [markdown]
# # INV-M365-CO persona-action P1 notebook evidence scope correction v1
#
# ## Purpose
# - Freeze the exact `P1` code-write blocker from the active persona-action full-support remediation initiative.
# - Prove the parent initiative cannot start dead-route code repair until a phase-specific notebook-backed evidence surface exists.
#
# ## Lemma Mapping
# - Governance-only successor-package evidence for the `P1` notebook-backed dead-route remediation boundary.
#
# ## Invariant Support
# - `P1` code repair may only begin when the blocked write set, denial reason, and future dead-route evidence chain are explicit.
#
# ## Expected Results
# - The certified dead-route backlog is frozen deterministically.
# - The exact MCP denial is frozen deterministically.
# - The successor `P1S` package and the future `L89` evidence chain are recorded explicitly.

# %%
analysis = {
    "status": "passed",
    "parent_plan_id": "plan:m365-persona-action-full-support-remediation",
    "blocked_phase": "P1",
    "certified_dead_route_backlog": {
        "active_pairs": 116,
        "unique_aliases": 21
    },
    "blocked_write_set": [
        "src/ops_adapter/actions.py",
        "src/smarthaus_common/permission_enforcer.py",
        "policies/ops.rego",
        "tests/test_ops_adapter.py",
        "tests/test_policies.py",
        "tests/test_executor_routing_v2.py"
    ],
    "governance_denial": {
        "action_type": "file_edit",
        "target": "first P1 dead-route code repair",
        "violation": "map-2-code-notebook-required",
        "allowed": False
    },
    "existing_supporting_evidence": {
        "notebooks": [
            "notebooks/m365/INV-M365-CK-persona-action-mapping-audit-v1.ipynb",
            "notebooks/m365/INV-M365-CN-persona-action-route-certification-v1.ipynb"
        ],
        "scorecards": [
            "artifacts/scorecards/scorecard_l86.json",
            "artifacts/scorecards/scorecard_l88.json"
        ]
    },
    "successor_package_required": True,
    "successor_package": "plan:m365-persona-action-p1-notebook-evidence-scope-correction",
    "future_dead_route_evidence_chain": {
        "lemma": "docs/ma/lemmas/L89_m365_persona_action_dead_route_remediation_v1.md",
        "invariant": "invariants/lemmas/L89_m365_persona_action_dead_route_remediation_v1.yaml",
        "notebook": "notebooks/m365/INV-M365-CP-persona-action-dead-route-remediation-v1.ipynb",
        "lemma_notebook": "notebooks/lemma_proofs/L89_m365_persona_action_dead_route_remediation_v1.ipynb",
        "scorecard": "artifacts/scorecards/scorecard_l89.json",
        "verification": "configs/generated/persona_action_dead_route_remediation_v1_verification.json"
    }
}

assert analysis["status"] == "passed"
assert analysis["certified_dead_route_backlog"]["active_pairs"] == 116
assert analysis["certified_dead_route_backlog"]["unique_aliases"] == 21
assert analysis["governance_denial"]["violation"] == "map-2-code-notebook-required"
assert analysis["successor_package_required"] is True
assert len(analysis["blocked_write_set"]) == 6
analysis

# %% [markdown]
# ## Deterministic Verification Contract
# - The parent initiative remains paused at `P1S` until notebook-backed blocker evidence exists.
# - The first `P1` file-edit validation may only be retried under child-plan authority.
# - The future `L89` dead-route notebook chain must be explicit before the code repair phase proceeds.

# %%
verification = {
    "status": analysis["status"],
    "parent_plan_id": analysis["parent_plan_id"],
    "blocked_phase": analysis["blocked_phase"],
    "certified_dead_route_backlog": analysis["certified_dead_route_backlog"],
    "blocked_write_set": analysis["blocked_write_set"],
    "governance_denial": analysis["governance_denial"],
    "successor_package_required": analysis["successor_package_required"],
    "successor_package": analysis["successor_package"],
    "future_dead_route_evidence_chain": analysis["future_dead_route_evidence_chain"]
}

assert verification["status"] == "passed"
assert verification["successor_package_required"] is True
verification
