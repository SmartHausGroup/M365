# %% [markdown]
# # INV-M365-CS Persona-Action P2 Second-Wave Notebook Evidence Scope Correction v1
#
# Purpose: freeze the bounded second-wave `P2` blocker truth so the parent remediation may reopen the blocked legacy-stub code-write validation.
#
# Lemma mapping:
# - `L91_m365_persona_action_legacy_stub_remediation_v2`
#
# Invariant support:
# - `L91_m365_persona_action_legacy_stub_remediation_v2.yaml`

# %%
verification = {
    "status": "persona_action_p2_second_wave_notebook_evidence_scope_correction_ready",
    "blocked_write_set": [
        "src/ops_adapter/actions.py",
        "tests/test_ops_adapter.py",
    ],
    "target_aliases": [
        "followup.create",
        "client.follow-up",
        "satisfaction.survey",
        "interview.schedule",
    ],
    "legacy_stub_backlog": {"active_pairs": 45, "unique_aliases": 45},
    "blocked_validation": {"verdict": "allowed:false", "violation": "map-2-code-notebook-required"},
    "future_l91_chain": {
        "lemma": "docs/ma/lemmas/L91_m365_persona_action_legacy_stub_remediation_v2.md",
        "invariant": "invariants/lemmas/L91_m365_persona_action_legacy_stub_remediation_v2.yaml",
        "notebook": "notebooks/m365/INV-M365-CT-persona-action-legacy-stub-remediation-v2.ipynb",
        "lemma_notebook": "notebooks/lemma_proofs/L91_m365_persona_action_legacy_stub_remediation_v2.ipynb",
        "scorecard": "artifacts/scorecards/scorecard_l91.json",
        "verification": "configs/generated/persona_action_legacy_stub_remediation_v2_verification.json"
    }
}
assert verification["legacy_stub_backlog"]["unique_aliases"] == 45
assert verification["blocked_validation"]["violation"] == "map-2-code-notebook-required"
verification
