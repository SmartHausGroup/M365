# %% [markdown]
# # INV-M365-AN — Intune / Devices Expansion v2
#
# Purpose: prove the bounded Intune/device workload authority, runtime projection, routing, auth, approvals, and verification contract for `E4A`.
#
# Lemma mapping: `L38_m365_intune_devices_expansion_v2`.
#
# Invariant support: `invariants/lemmas/L38_m365_intune_devices_expansion_v2.yaml`.
#
# Expected result: all declared device actions are instruction-backed, capability-backed, routed to `devices`, app-only, approval-profile aligned, and bounded to realistic Intune managed-device surfaces.

# %% [markdown]
# Deterministic validation is extracted into `scripts/ci/verify_intune_devices_expansion.py` and `tests/test_intune_devices_expansion_v2.py`. Runtime code is only accepted after those bounded proofs remain green.
