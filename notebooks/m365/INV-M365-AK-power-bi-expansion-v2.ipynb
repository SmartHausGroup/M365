# %% [markdown]
# # INV-M365-AK — Power BI Expansion v2
#
# Purpose: prove the bounded Power BI workload authority, runtime projection, routing, auth, approvals, and verification contract for `E3C`.
#
# Lemma mapping: `L35_m365_power_bi_expansion_v2`.
#
# Invariant support: `invariants/lemmas/L35_m365_power_bi_expansion_v2.yaml`.
#
# Expected result: all declared Power BI actions are instruction-backed, capability-backed, routed to `powerplatform`, app-only, and approval-profile aligned.

# %% [markdown]
# Deterministic validation is extracted into `scripts/ci/verify_power_bi_expansion.py` and `tests/test_power_bi_expansion_v2.py`. Runtime code is only accepted after those bounded proofs remain green.
