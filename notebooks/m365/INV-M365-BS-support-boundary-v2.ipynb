# %% [markdown]
# # Purpose
#
# Prove support boundary v2 is bounded and deterministic.
#
# ## Lemma: L71

# %%
from pathlib import Path
import yaml

repo_root = Path.cwd()
contract = yaml.safe_load((repo_root / 'registry' / 'support_boundary_v2.yaml').read_text(encoding='utf-8'))
assert contract['contract']['id'] == 'support-boundary-v2'
assert len(contract['support_layers']) == 4
assert len(contract['governance_rules']) == 5
assert contract['kpis']['support_tier_count'] == 3
