# %% [markdown]
# # INV-M365-J: Scripts and CI Ruff Cleanup
#
# Purpose: prove the scoped tooling cleanup required before runtime Ruff/Black work and full validation closure can proceed.
#
# Invariant support: `L8_m365_scripts_ci_ruff_cleanup`.
#
# Expected result: the pinned scripts and CI Ruff surface reaches zero violations without widening into runtime, notebook-format, or mypy-only work.

# %%
TOOLING_SCOPE = [
    "scripts/",
    "scripts/ci/",
]
TOOLING_SCOPE
