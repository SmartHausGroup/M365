# %% [markdown]
# # INV-M365-I: Validation Blocker Recovery
#
# Purpose: prove the narrow syntax-gate required before repo-wide Ruff/Black/Mypy remediation can be trusted.
#
# Invariant support: `L7_m365_validation_blocker_recovery`.
#
# Expected result: `scripts/generate-policies.py` parses under Python and the known malformed invariants load under YAML without widening scope into unrelated lint cleanup.

# %%
BLOCKER_FILES = [
    "scripts/generate-policies.py",
    "governance/invariants/m365/INV-M365-B-001.yaml",
    "governance/invariants/m365/INV-M365-E-001.yaml",
    "governance/invariants/m365/INV-M365-F-001.yaml",
    "governance/invariants/m365/INV-M365-G-001.yaml",
]
BLOCKER_FILES
