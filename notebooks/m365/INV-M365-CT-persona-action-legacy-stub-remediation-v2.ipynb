# %% [markdown]
# # INV-M365-CT Persona-Action Legacy-Stub Remediation v2
#
# Purpose: define the second bounded legacy-stub remediation wave for `P2`.

# %%
verification = {
    "status": "persona_action_legacy_stub_remediation_v2_ready",
    "target_aliases": [
        "followup.create",
        "client.follow-up",
        "satisfaction.survey",
        "interview.schedule",
    ],
    "blocked_write_set": ["src/ops_adapter/actions.py", "tests/test_ops_adapter.py"],
    "replacement_modes": {
        "followup.create": "calendar_create",
        "client.follow-up": "calendar_create",
        "satisfaction.survey": "mail_send",
        "interview.schedule": "calendar_create"
    }
}
assert verification["replacement_modes"]["satisfaction.survey"] == "mail_send"
verification
