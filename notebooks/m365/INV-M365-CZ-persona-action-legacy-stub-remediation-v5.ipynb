# %% [markdown]
# # INV-M365-CZ persona-action legacy-stub remediation v5
#
# - Lemma: L94
# - Target aliases: infrastructure.monitor, backup.verify, security.scan.
# - Planned outcomes: two real rebinds plus one explicit unsupported failure.
