# %% [markdown]
# # INV-M365-K: Runtime, CLI, and Notebook Validation Cleanup
#
# Purpose: prove the scoped runtime, CLI, governed-test, and notebook cleanup required before Mypy remediation and full repo validation closure can proceed.
#
# Invariant support: `L9_m365_runtime_cli_notebook_validation_cleanup`.
#
# Expected result: the pinned execution-surface Ruff and formatter debt is eliminated without widening into Mypy-only work or unrelated repo spillover.

# %%
EXECUTION_SCOPE = [
    "src/ops_adapter/",
    "src/provisioning_api/",
    "src/smarthaus_cli/",
    "src/smarthaus_common/",
    "tests/test_policies.py",
    "notebooks/",
]
EXECUTION_SCOPE
