# %% [markdown]
# # INV-M365-AU — Persona Task Queues and State v1
#
# ## Purpose
# Prove the deterministic queue/state contract for digital employees.
#
# ## Lemma Mapping
# - L45
#
# ## Invariant Support
# - invariants/lemmas/L45_m365_persona_task_queue_state_v1.yaml
#
# ## Expected Result
# - One shared queue projection across dashboard and persona runtime.

# %% [markdown]
# ## Runtime Extraction Boundary
# - src/smarthaus_common/json_store.py
# - src/smarthaus_common/persona_task_queue.py
# - src/provisioning_api/routers/agent_dashboard.py
# - src/ops_adapter/main.py
# - src/ops_adapter/app.py
