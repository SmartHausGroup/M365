# %% [markdown]
# # INV-M365-AP — Compliance / Retention / eDiscovery Expansion v2
#
# - Purpose: bound the E4C Microsoft 365 Purview / eDiscovery slice.
# - Lemma mapping: L40.
# - Invariant support: `L40_m365_compliance_retention_ediscovery_expansion_v2`.
# - Expected result: router, registries, and verifier agree on the same eight-action surface.
