# %% [markdown]
# # INV-M365-AO — Security / Defender Expansion v2
#
# - Purpose: Bound the E4B security / Defender slice.
# - Lemma mapping: L39.
# - Invariant support: `L39_m365_security_defender_expansion_v2`.
# - Expected result: router, registry, auth, approval, and verifier agreement for the E4B action family.
