# %% [markdown]
# # INV-M365-S Persona Registry and Humanized Delegation Integration
#
# Purpose: back `B7C` by proving that named digital employees can resolve deterministically to governed runtime agents while preserving bounded executor, approval, and audit semantics.
#
# Lemma mapping: `L17`
#
# Invariant support: `L17_m365_persona_registry_humanized_delegation_integration.yaml`
#
# Expected result: persona aliases map deterministically, inactive or unmapped personas fail closed, and persona context is preserved through approvals and audit.
