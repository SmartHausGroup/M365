# %% [markdown]
# # INV-M365-Q Tenant Contract and Executor Registry Extension
#
# Purpose: back `B7A` by proving that the tenant contract can represent bounded executors while preserving the legacy default executor path.
#
# Lemma mapping: `L15`
#
# Invariant support: `INV-M365-Q`
#
# Expected result: the config loader accepts explicit executor definitions, resolves one deterministic default executor, and preserves backward-compatible root auth fields.
