# %% [markdown]
# # L37 Proof Notebook
#
# This notebook projects the `L37` bounded cross-workload recipe proof into the runtime enforcement surface.

# %% [markdown]
# Proof obligation: the recipe authority, instruction router, capability registry, executor routing, auth model, approval matrix, and bounded verifier all agree on the same implemented recipe-catalog action set, and each recipe remains cross-workload.
