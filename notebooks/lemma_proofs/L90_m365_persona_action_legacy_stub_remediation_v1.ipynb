# %% [markdown]
# # L90 Lemma Proof Notebook

# %%
verification = {
    "target_aliases": ["task.create", "follow-up.schedule", "reminder.send"],
    "replacement_modes": {
        "task.create": "planner_create_task",
        "follow-up.schedule": "calendar_create",
        "reminder.send": "mail_send"
    }
}
assert len(verification["target_aliases"]) == 3
assert verification["replacement_modes"]["reminder.send"] == "mail_send"
verification
