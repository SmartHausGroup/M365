# %% [markdown]
# # L3 CAIO M365 Authentication Projection
#
# Projection notebook for the existing authentication proof. Source proof notebook: `notebooks/ma_m365_auth.ipynb`.

# %%
import json
from pathlib import Path

artifact = json.loads(Path('configs/generated/m365_auth_verification.json').read_text())
assert artifact['auth_pass'] is True
print('L3 green')
