# %% [markdown]
# # L36 Proof Notebook
#
# This notebook projects the `L36` bounded Forms / Approvals / Connectors expansion proof into the runtime enforcement surface.

# %% [markdown]
# Proof obligation: the workload authority, instruction router, capability registry, executor routing, auth model, approval matrix, and bounded verifier all agree on the same implemented approvals-app and connector action set.
