# %% [markdown]
# # L41 Proof Notebook — Conditional Access / Identity Protection Expansion v2
#
# - Source notebook: `notebooks/m365/INV-M365-AQ-conditional-access-identity-protection-expansion-v2.ipynb`
# - Lemma: `L41`
# - Expected result: deterministic agreement for the E4D action family.
