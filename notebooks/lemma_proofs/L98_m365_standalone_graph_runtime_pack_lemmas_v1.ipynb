# %% [markdown]
# # Lemma Proof L98 - M365 Standalone Graph Runtime Pack Lemmas v1
# **Plan:** `plan:m365-standalone-graph-runtime-integration-pack:R3`
# **Source lemma:** `docs/ma/lemmas/L98_m365_standalone_graph_runtime_pack_lemmas_v1.md`
# **Source invariant:** `invariants/lemmas/L98_m365_standalone_graph_runtime_pack_lemmas_v1.yaml`
# **Companion evidence:** `notebooks/m365/INV-M365-DM-standalone-graph-runtime-pack-p2-lemmas-v1.ipynb`
# **Generated verification:** `configs/generated/standalone_graph_runtime_integration_pack_p2_lemmas_v1_verification.json`
#
# This proof binds the seven lemmas into one bundled `StandaloneRuntimeTruth` predicate and proves the green base case plus seventeen targeted negative cases. The companion evidence notebook `INV-M365-DM` is the canonical execution; this proof is the lemma-side anchor.

# %%
import json
from pathlib import Path
verification = json.loads(Path('/Users/smarthaus/Projects/GitHub/M365/configs/generated/standalone_graph_runtime_integration_pack_p2_lemmas_v1_verification.json').read_text())
assert verification['truthful'] is True
assert verification['green_base_case_truth'] is True
assert len(verification['negative_cases']) == 17
assert set(verification['lemmas']) == {'L_STANDALONE','L_LAUNCH','L_AUTH','L_PERMISSIONS','L_READINESS','L_AUDIT','L_PACKAGING'}
verification['phase'], verification['truthful']
