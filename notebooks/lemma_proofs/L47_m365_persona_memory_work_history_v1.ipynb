# %% [markdown]
# # L47 Persona Memory and Work History v1 Proof
#
# This lemma-proof notebook projects the E5E runtime claim that bounded memory entries and replayable work history remain aligned only when the dashboard and persona runtime read from one memory/work-history authority and one shared runtime.

# %%
from pathlib import Path

root = Path.cwd()
paths = [
    root / 'registry' / 'persona_memory_work_history_v1.yaml',
    root / 'src' / 'smarthaus_common' / 'persona_memory.py',
    root / 'src' / 'provisioning_api' / 'routers' / 'agent_dashboard.py',
]
assert all(path.exists() for path in paths)
