# %% [markdown]
# # Lemma Proof — L88

# %%
from pathlib import Path
import json

repo = Path('/Users/smarthaus/Projects/GitHub/M365')
lemma_text = (repo / 'docs/ma/lemmas/L88_m365_persona_action_route_certification_v1.md').read_text()
verification = json.loads((repo / 'configs/generated/persona_action_route_certification_v1_verification.json').read_text())

assert '56' in lemma_text
assert '`1` green' in lemma_text
assert '`15` permission-blocked' in lemma_text
assert '`40` fenced' in lemma_text
assert verification['final_active_pair_matrix']['total'] == 430
'lemma_proof_ok'
