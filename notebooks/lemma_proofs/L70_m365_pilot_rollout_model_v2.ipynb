# %% [markdown]
# # L70 Proof Replay

# %%
from pathlib import Path
import yaml

repo_root = Path.cwd()
contract = yaml.safe_load((repo_root / 'registry' / 'pilot_rollout_model_v2.yaml').read_text(encoding='utf-8'))
assert len(contract['rollout_phases']) == 4
assert len(contract['governance_rules']) == 5
assert contract['kpis']['rollout_wave_count'] == 3
