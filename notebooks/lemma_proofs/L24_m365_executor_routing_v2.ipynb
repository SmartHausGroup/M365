# %% [markdown]
# # L24 Proof Notebook — Executor Routing v2
#
# Projected lemma notebook for deterministic executor routing.

# %%
from smarthaus_common.executor_routing import executor_route_for_action

assert executor_route_for_action(None, "collaboration.team.create") == "collaboration"
assert executor_route_for_action(None, "create_site") == "sharepoint"
