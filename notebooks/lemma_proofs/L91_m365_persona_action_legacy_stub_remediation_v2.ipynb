# %% [markdown]
# # L91 Lemma Proof Notebook

# %%
verification = {
    "target_aliases": [
        "followup.create",
        "client.follow-up",
        "satisfaction.survey",
        "interview.schedule",
    ],
    "replacement_modes": {
        "followup.create": "calendar_create",
        "client.follow-up": "calendar_create",
        "satisfaction.survey": "mail_send",
        "interview.schedule": "calendar_create"
    }
}
assert len(verification["target_aliases"]) == 4
assert verification["replacement_modes"]["client.follow-up"] == "calendar_create"
verification
