# %% [markdown]
# # L13 Proof Projection — Entra App Separation and Certificate Cutover
#
# This projected proof notebook binds `L13` to the governed SMARTHAUS auth-architecture cleanup required before standalone `C1A` may resume.
