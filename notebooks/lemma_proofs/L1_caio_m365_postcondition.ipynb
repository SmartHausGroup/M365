# %% [markdown]
# # L1 CAIO M365 Postcondition Projection
#
# Projection notebook for the existing CAIO ↔ M365 contract proof. Source proof notebook: `notebooks/ma_caio_m365_contract.ipynb`.

# %%
import json
from pathlib import Path

artifact = json.loads(Path('configs/generated/caio_m365_contract_verification.json').read_text())
assert artifact['response_schema_pass'] is True
assert artifact['postcondition_pass'] is True
print('L1 green')
