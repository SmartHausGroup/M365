# %% [markdown]
# # L8 M365 Scripts and CI Ruff Cleanup
#
# Projection notebook for the scripts and CI Ruff cleanup lemma. Source execution is governed by `docs/prompts/codex-m365-enterprise-readiness-master-plan-b4d2-scripts-ci-ruff-cleanup.md`.
