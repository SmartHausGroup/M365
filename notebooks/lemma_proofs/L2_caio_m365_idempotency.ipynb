# %% [markdown]
# # L2 CAIO M365 Idempotency Projection
#
# Projection notebook for the existing idempotency proof. Source proof notebook: `notebooks/ma_m365_idempotency.ipynb`.

# %%
import json
from pathlib import Path

artifact = json.loads(Path('configs/generated/m365_idempotency_verification.json').read_text())
assert artifact['idempotency_pass'] is True
print('L2 green')
