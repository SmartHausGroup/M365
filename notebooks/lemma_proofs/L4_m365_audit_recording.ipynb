# %% [markdown]
# # L4 M365 Audit Recording Projection
#
# Projection notebook for the existing audit proof. Source proof notebook: `notebooks/ma_m365_audit.ipynb`.

# %%
import json
from pathlib import Path

artifact = json.loads(Path('configs/generated/m365_audit_verification.json').read_text())
assert artifact['audit_pass'] is True
print('L4 green')
