# %% [markdown]
# # L33 Proof Notebook — M365 Power Automate Expansion v2
#
# - Lemma: `L33`.
# - Invariant: `L33_m365_power_automate_expansion_v2`.
# - Scope: prove that the Power Automate workload slice is instruction-backed, capability-registered, executor-routed to `powerplatform`, auth-bounded to `app_only`, and synchronized with the active plan.

# %% [markdown]
# ## Proof sketch
#
# 1. The action surface is emitted from `src/provisioning_api/routers/m365.py`.
# 2. The bounded runtime lives in `src/smarthaus_common/power_automate_client.py`.
# 3. The machine authorities are `registry/power_automate_expansion_v2.yaml`, `registry/executor_routing_v2.yaml`, `registry/auth_model_v2.yaml`, and `registry/approval_risk_matrix_v2.yaml`.
# 4. The verifier and tests certify the act and force fail-closed behavior on missing runtime prerequisites.
