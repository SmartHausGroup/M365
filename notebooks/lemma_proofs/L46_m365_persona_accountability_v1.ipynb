# %% [markdown]
# # L46 Persona Accountability v1 Proof
#
# This lemma-proof notebook projects the E5D runtime claim that ownership, KPI thresholds, accountability state, and escalation target remain aligned only when the dashboard and persona runtime read from one accountability authority and one shared queue runtime.

# %%
from pathlib import Path

root = Path.cwd()
paths = [
    root / 'registry' / 'persona_accountability_v1.yaml',
    root / 'registry' / 'persona_registry_v2.yaml',
    root / 'src' / 'smarthaus_common' / 'persona_accountability.py',
    root / 'src' / 'provisioning_api' / 'routers' / 'agent_dashboard.py',
]
assert all(path.exists() for path in paths)
