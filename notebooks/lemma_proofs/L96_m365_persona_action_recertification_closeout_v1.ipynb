# %% [markdown]
# # L96 Proof Notebook — Persona-Action Recertification Closeout v1
#
# - Purpose: replay the final `P5` recertification arithmetic from the published verification payload.
# - Lemma: `L96_m365_persona_action_recertification_closeout_v1`.
# - Correctness criterion: the alias and pair matrices sum exactly to the live post-remediation universe and leave no non-fenced residue.

# %%
verification = {
    "live_universe": {"unique_aliases_total": 172, "active_pairs_total": 445},
    "final_unique_alias_matrix": {"green": 103, "approval-gated": 36, "actor-tier-gated": 1, "fenced": 32, "permission-blocked": 0, "legacy-stubbed": 0, "dead-routed": 0, "orphaned": 0},
    "final_active_pair_matrix": {"green": 360, "approval-gated": 49, "actor-tier-gated": 1, "fenced": 35, "permission-blocked": 0, "legacy-stubbed": 0, "dead-routed": 0, "orphaned": 0},
}

assert sum(verification["final_unique_alias_matrix"].values()) == 172
assert sum(verification["final_active_pair_matrix"].values()) == 445
assert verification["final_unique_alias_matrix"]["permission-blocked"] == 0
assert verification["final_unique_alias_matrix"]["legacy-stubbed"] == 0
assert verification["final_unique_alias_matrix"]["dead-routed"] == 0
assert verification["final_unique_alias_matrix"]["orphaned"] == 0
assert verification["final_active_pair_matrix"]["permission-blocked"] == 0
assert verification["final_active_pair_matrix"]["legacy-stubbed"] == 0
assert verification["final_active_pair_matrix"]["dead-routed"] == 0
assert verification["final_active_pair_matrix"]["orphaned"] == 0
verification
